# %%
import sys

sys.path.append("../src")

# %%
import joblib
import pandas as pd
import shap

from preprocessing import prepare_data

# %%
(
    X_train_scaled,
    X_test_scaled,
    y_train,
    y_test,
    scaler,
    X_train,
    X_test
) = prepare_data("D:\GenAI\MACHINE LEARNING\AI FRAUD DETECTION\DATA\creditcard.csv")
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\G'
# <>:9: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Nishita\AppData\Local\Temp\ipykernel_27336\2242950923.py:9: SyntaxWarning: invalid escape sequence '\G'
#   ) = prepare_data("D:\GenAI\MACHINE LEARNING\AI FRAUD DETECTION\DATA\creditcard.csv")

# %%
import joblib

model = joblib.load(
    "D:\\GenAI\\MACHINE LEARNING\\AI FRAUD DETECTION\\models\\xgboost_model.pkl"
)

print("XGBoost model loaded successfully!")
# Out:
# XGBoost model loaded successfully!

# %%
explainer = shap.TreeExplainer(model)

# %%
shap_values = explainer.shap_values(X_test)

# %%
feature_names = X_test.columns

# %%
shap.summary_plot(
    shap_values,
    X_test,
    feature_names=feature_names
)

# %%
shap.summary_plot(
    shap_values,
    X_test,
    feature_names=feature_names,
    plot_type="bar"
)
